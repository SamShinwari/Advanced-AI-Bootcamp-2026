# %% [markdown]
# <a href="https://colab.research.google.com/github/SamShinwari/Advanced-AI-Bootcamp-2026/blob/main/Day_1_Tuple_and_their_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Day 2: Python Tuples for AI, NLP, LLMs & Agentic AI

## What is a Tuple?

A **tuple** is an ordered, immutable (cannot be changed after creation) collection of items in Python. Tuples are used to store **fixed data** that should remain constant throughout a program.

**Syntax:**

```python
my_tuple = (item1, item2, item3)
```

**Key Features**

* Ordered collection
* Immutable (cannot add, remove, or modify elements)
* Allows duplicate values
* Faster than lists for fixed data
* Can store different data types

---

# %% [markdown]
# # 1. Creating a Tuple

# %%
numbers = (10, 20, 30, 40, 50)

print(numbers)
# Out:
# (10, 20, 30, 40, 50)

# %% [markdown]
# ### AI Application
#
# Store fixed mathematical constants or model parameters that should never change.
#
# ---

# %% [markdown]
# # 2. Tuple of AI Models

# %%
models = (
    "Linear Regression",
    "Decision Tree",
    "Random Forest",
    "Transformer"
)

print(models)
# Out:
# ('Linear Regression', 'Decision Tree', 'Random Forest', 'Transformer')

# %% [markdown]
# ### Application
#
# Store a fixed list of supported AI models.
#
# ---

# %% [markdown]
# # 3. Accessing Tuple Elements

# %%
frameworks = (
    "NumPy",
    "Pandas",
    "PyTorch",
    "TensorFlow"
)

print(frameworks[0])
print(frameworks[2])
print(frameworks[-1])
# Out:
# NumPy
# PyTorch
# TensorFlow

# %% [markdown]
# ### Application
#
# Access predefined frameworks used in an AI project.
#
# ---

# %% [markdown]
# # 4. Tuple Packing

# %%
student = ("Ali", 24, "AI")

print(student)
# Out:
# ('Ali', 24, 'AI')

# %% [markdown]
# ### Application
#
# Store fixed student information or experiment metadata.
#
# ---

# %% [markdown]
# # 5. Tuple Unpacking

# %%
name, age, field = ("Ali", 24, "AI")

print(name)
print(age)
print(field)
# Out:
# Ali
# 24
# AI

# %% [markdown]
# ### Application
#
# Retrieve experiment information efficiently.
#
# ---

# %% [markdown]
# # 6. Loop Through a Tuple

# %%
languages = (
    "Python",
    "R",
    "Julia",
    "Java"
)

for language in languages:
    print(language)
# Out:
# Python
# R
# Julia
# Java

# %% [markdown]
# ### Application
#
# Display supported programming languages.
#
# ---

# %% [markdown]
# # 7. Tuple Length

# %%
datasets = (
    "IMDB",
    "SQuAD",
    "Common Crawl",
    "WikiText"
)

print(len(datasets))
# Out:
# 4

# %% [markdown]
# ### Application
#
# Count the number of available datasets.
#
# ---

# %% [markdown]
# # Real AI Applications

# %% [markdown]
# ## Example 1: Model Input Shape

# %%
input_shape = (224, 224, 3)

print(input_shape)
# Out:
# (224, 224, 3)

# %% [markdown]
# ### Why Tuple?
#
# Image dimensions remain fixed during training.
#
# ---

# %% [markdown]
# ## Example 2: Transformer Configuration

# %%
transformer_config = (
    768,      # Hidden size
    12,       # Attention heads
    12        # Encoder layers
)

print(transformer_config)
# Out:
# (768, 12, 12)

# %% [markdown]
# ### Application
#
# Transformer architecture settings should remain constant after model creation.
#
# ---

# %% [markdown]
# ## Example 3: NLP Dataset Information

# %%
dataset = (
    "Pashto News Dataset",
    25000,
    "Pashto"
)

print(dataset)
# Out:
# ('Pashto News Dataset', 25000, 'Pashto')

# %% [markdown]
# ### Application
#
# Store fixed dataset metadata.
#
# ---

# %% [markdown]
# ## Example 4: Training Configuration

# %%
training = (
    32,
    5,
    0.001
)

print(training)
# Out:
# (32, 5, 0.001)

# %% [markdown]
# ### Meaning
#
# * Batch Size = 32
# * Epochs = 5
# * Learning Rate = 0.001
#
# These values are often treated as fixed during an experiment.
#
# ---

# %% [markdown]
# ## Example 5: Token Position

# %%
token = ("Artificial", 15)

print(token)
# Out:
# ('Artificial', 15)

# %% [markdown]
# ### Application
#
# Store a token and its position in a sentence.
#
# ---

# %% [markdown]
# ## Example 6: LLM Message Pair

# %%
message = (
    "User",
    "Explain Attention Mechanism."
)

print(message)
# Out:
# ('User', 'Explain Attention Mechanism.')

# %% [markdown]
# ### Application
#
# Represent a chat message as an immutable `(role, content)` pair.
#
# ---

# %% [markdown]
# ## Example 7: RAG Search Result

# %%
document = (
    102,
    "Transformer Architecture",
    0.97
)

print(document)
# Out:
# (102, 'Transformer Architecture', 0.97)

# %% [markdown]
# ### Meaning
#
# * Document ID
# * Title
# * Similarity Score
#
# Useful for retrieval systems.
#
# ---

# %% [markdown]
# ## Example 8: Multi-Agent Task

# %%
task = (
    "Research Agent",
    "Collect AI papers"
)

print(task)
# Out:
# ('Research Agent', 'Collect AI papers')

# %% [markdown]
# ### Application
#
# Store a fixed assignment for an AI agent.
#
# ---

# %% [markdown]
# ## Example 9: GPU Information

# %%
gpu = (
    "NVIDIA RTX 4090",
    24,
    "CUDA"
)

print(gpu)
# Out:
# ('NVIDIA RTX 4090', 24, 'CUDA')

# %% [markdown]
# ### Application
#
# Store hardware specifications that do not change during execution.
#
# ---

# %% [markdown]
# ## Example 10: Model Performance

# %%
metrics = (
    98.2,
    97.4,
    96.8
)

print(metrics)
# Out:
# (98.2, 97.4, 96.8)

# %% [markdown]
# ### Meaning
#
# * Accuracy
# * Precision
# * Recall
#
# Store evaluation metrics as a fixed result.
#
# ---

# %% [markdown]
# # Why Use Tuples Instead of Lists in AI?
#
# | List                     | Tuple                        |
# | :----------------------- | :--------------------------- |
# | Mutable                  | Immutable                    |
# | Can add/remove items     | Cannot add/remove items      |
# | Slightly slower          | Slightly faster              |
# | Used for dynamic data    | Used for fixed data          |
# | Example: Dataset samples | Example: Model configuration |
#
# ---

# %% [markdown]
# # Common AI Uses of Tuples
#
# * ✅ Model input/output shapes
# * ✅ Image dimensions `(224, 224, 3)`
# * ✅ Transformer hyperparameters
# * ✅ Dataset metadata
# * ✅ Training configurations
# * ✅ Token-position pairs
# * ✅ Chat message `(role, message)`
# * ✅ RAG retrieval results
# * ✅ Multi-agent task assignments
# * ✅ Evaluation metrics
# * ✅ Hardware specifications
#
# ---

# %% [markdown]
# # Day 2 Summary
#
# By the end of Day 2, you should know how to:
#
# * ✅ Create tuples
# * ✅ Access tuple elements
# * ✅ Pack and unpack tuples
# * ✅ Iterate through tuples
# * ✅ Understand tuple immutability
# * ✅ Use tuples to store fixed AI configurations
# * ✅ Represent model shapes, hyperparameters, and metadata
# * ✅ Apply tuples in NLP, Transformers, LLMs, RAG, and Agentic AI projects
#
# Tuples are especially useful in AI because they protect **fixed configurations and metadata** from accidental modification, making code more reliable and easier to maintain.
